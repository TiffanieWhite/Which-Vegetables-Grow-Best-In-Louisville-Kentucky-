# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.1 MB 1.0 MB/s eta 0:00:11
#    --- ------------------------------------ 1.0/11.1 MB 1.9 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/11.1 MB 2.1 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/11.1 MB 2.0 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/11.1 MB 1.9 MB/s eta 0:00:05
#    --------- ------------------------------ 2.6/11.1 MB 1.9 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.9/11.1 MB 2.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.9/11.1 MB 2.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.9/11.1 MB 2.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.1/11.1 MB 1.4 MB/s eta 0:00:06
# ...

# %%
import pandas as pd

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.3 MB 598.0 kB/s eta 0:00:13
#    --- ------------------------------------ 0.8/8.3 MB 772.9 kB/s eta 0:00:10
#    ----- ---------------------------------- 1.0/8.3 MB 952.7 kB/s eta 0:00:08
#    ----- ---------------------------------- 1.0/8.3 MB 952.7 kB/s eta 0:00:08
#    ------ --------------------------------- 1.3/8.3 MB 830.4 kB/s eta 0:00:09
#    ------- -------------------------------- 1.6/8.3 MB 867.2 kB/s eta 0:00:08
#    -------- ------------------------------- 1.8/8.3 MB 922.4 kB/s eta 0:00:07
#    ---------- ----------------------------- 2.1/8.3 MB 957.8 kB/s eta 0:00:07
# ...

# %% [markdown]
# #had to pip install pandas and matplotlib on loaner computer

# %%
#import pandas
import pandas as pd

# %%
pip install kaggle
# Out:
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    -------------- ------------------------- 0.5/1.5 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------ --- 1.3/1.5 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 3.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/10.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/10.3 MB 3.9 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/10.3 MB 4.6 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/10.3 MB 4.0 MB/s eta 0:00:02
#    ------------ --------------------------- 3.1/10.3 MB 3.9 MB/s eta 0:00:02
#    --------------- ------------------------ 3.9/10.3 MB 3.7 MB/s eta 0:00:02
#    ------------------ --------------------- 4.7/10.3 MB 3.9 MB/s eta 0:00:02
#    ------------------- -------------------- 5.0/10.3 MB 3.8 MB/s eta 0:00:02
# ...

# %% [markdown]
# # I was struggling to get my datasets over to VS code. Downloaded the pip from Kaggle to assist.
